# %% [markdown]
# LAB WORK 3

# %%
# !pip install scikit-image

# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
import random

# %%
image = data.camera()
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        image[i,j] += random.randint(-20,20)

# %%
plt.imshow(image, cmap = plt.cm.gray)

# %%
mm = np.median(image)
print(mm)
# Out:
# 153.0

# %%
binary = image > mm

# %%
plt.imshow(binary, cmap = plt.cm.gray)

# %%
from skimage import feature

edges1 = feature.canny(image,sigma=2,)

# %%
plt.imshow(edges1, cmap = plt.cm.gray)

# %%
edges2 = feature.canny(image,sigma=3.5)

# %%
plt.imshow(edges2, cmap = plt.cm.gray)

# %%
edges2 = feature.canny(image,sigma=1.5)
plt.imshow(edges2, cmap = plt.cm.gray)

# %%
image_norm= data.camera()
edges_norm = feature.canny(image_norm,sigma=2,)
plt.imshow(edges_norm, cmap = plt.cm.gray)
